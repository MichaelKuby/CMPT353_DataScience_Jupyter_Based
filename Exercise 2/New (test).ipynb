# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pylab as plt
from scipy import stats

# %%
data = pd.read_csv('dog_rates_tweets.csv')
data
# Out:
#                        id           created_at  \
# 0      994677639364403200  2018-05-10 20:36:44
# 1      994364904978239488  2018-05-09 23:54:02
# 2      994363623421153280  2018-05-09 23:48:56
# 3      994336722875047936  2018-05-09 22:02:03
# 4      994024065982717952  2018-05-09 01:19:40
# ...                   ...                  ...
# 8510  1027980978910687233  2018-08-10 18:12:18
# 8511  1027976875811819520  2018-08-10 17:56:00
# 8512  1027970381766963202  2018-08-10 17:30:12
# 8513  1027967697684815873  2018-08-10 17:19:32
# 8514  1027963039029452800  2018-08-10 17:01:01
#
#                                                    text
# 0                  @Steff88979267 tell them to h*ck off
# 1                             @NFLOwnerGBP take it back
# 2     This is Louie. He has misplaced his Cheerio. W...
# 3                                   @rachaellanaghan ❤️
# 4     This is Captain Jack Wobbles. He is currently ...
# ...                                                 ...
# ...

# %%
data['ratings'] = data['text'].str.extractall(r'(\d+(\.\d+)?)/10')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:11000, in _reindex_for_setitem(value, index)
#   10999 try:
# > 11000     reindexed_value = value.reindex(index)._values
#   11001 except ValueError as err:
#   11002     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:324, in rewrite_axis_style_signature.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     322 @wraps(func)
#     323 def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324     return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4804, in DataFrame.reindex(self, *args, **kwargs)
#    4803 kwargs.pop("labels", None)
# -> 4804 return super().reindex(**kwargs)
#
# ...
